# %%
# import libraries
import pandas as pd
import numpy as np
import os
import operator 
import re
import sys
from featurefunctions import create_text_column, features,normalized_features,count_features,tfidf_features,tfidf_ngram_features,tfidf_ngram_chars,ling_feature_vec,all_count_features,all_features
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\swcam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\swcam\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\swcam\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
##TODO

csv_file = '/Users/swcam/Documents/GitHub/Sarcasm/Twitter_test_label.csv'

df = pd.read_csv(csv_file)

# print out the first few rows of data info
df.head(2)
# Out:
#          label                                          context/0  \
# 0  NOT_SARCASM             Well now that ’ s problematic AF <URL>
# 1      SARCASM  Last week the Fake News said that a section of...
#
#                                            context/1  \
# 0  @USER @USER My 5 year old ... asked me why the...
# 1  @USER The mainstream media doesn't report the ...
#
#                                            context/2  \
# 0  @USER @USER @USER I will take shit that didn't...
# 1                                                NaN
#
#                                            context/3  \
# 0  @USER @USER @USER No .. he actually in the gif...
# 1                                                NaN
#
#                                             response         id context/4  \
# 0  @USER @USER @USER My 3 year old , that just fi...  twitter_1       NaN
# 1  @USER @USER How many verifiable lies has he to...  twitter_2       NaN
#
#   context/5 context/6  ... context/8 context/9 context/10 context/11  \
# 0       NaN       NaN  ...       NaN       NaN        NaN        NaN
# 1       NaN       NaN  ...       NaN       NaN        NaN        NaN
#
#   context/12 context/13 context/14 context/15 context/16 context/17
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
#
# [2 rows x 21 columns]

# %%
df['concat_tweet'] = df['response'].str.cat(df['context/0'],sep=" ")
df
# Out:
#             label                                          context/0  \
# 0     NOT_SARCASM             Well now that ’ s problematic AF <URL>
# 1         SARCASM  Last week the Fake News said that a section of...
# 2         SARCASM  @USER Let ’ s Aplaud Brett When he deserves it...
# 3     NOT_SARCASM  Women generally hate this president . What's u...
# 4     NOT_SARCASM  Dear media Remoaners , you excitedly sharing c...
# ...           ...                                                ...
# 1795  NOT_SARCASM  I have been a business customer of MWeb @USER ...
# 1796      SARCASM  A woman refuses to have her temperature taken ...
# 1797      SARCASM  The reason big government wants @USER out is b...
# 1798  NOT_SARCASM  Happy #musicmonday and #thanks for #all your 😎...
# 1799  NOT_SARCASM  Not long wrapped on the amazing #January22nd W...
#
#                                               context/1  \
# 0     @USER @USER My 5 year old ... asked me why the...
# 1     @USER The mainstream media doesn't report the ...
# 2     @USER @USER He did try keep korkmaz in in the ...
# 3     @USER I've hated him before he was placed in o...
# 4     @USER When Spiked claim that Brexiteers knew e...
# ...                                                 ...
# 1795  @USER @USER It ’ s time for @USER , 24/7 frien...
# 1796           @USER Disgusting i hope this world burns
# 1797  @USER @USER They ’ re already not allowed , it...
# 1798  @USER @USER @USER Happy #MusicMonday to you to...
# 1799  @USER @USER Two phenomenal women . Much love t...
#
#                                               context/2  \
# 0     @USER @USER @USER I will take shit that didn't...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     @USER @USER Quite an articulate and considered...
# ...                                                 ...
# 1795                                                NaN
# 1796                                                NaN
# 1797  @USER @USER @USER Tell Obama that . Throughout...
# 1798  @USER @USER @USER Hi have listened to 2020 New...
# 1799  @USER @USER Hey Roy , thanks very much for bei...
#
#                                               context/3  \
# 0     @USER @USER @USER No .. he actually in the gif...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1795                                                NaN
# 1796                                                NaN
# 1797                                                NaN
# 1798  @USER @USER @USER #sorry just #stop me if i #a...
# 1799                                                NaN
#
#                                                response            id  \
# 0     @USER @USER @USER My 3 year old , that just fi...     twitter_1
# 1     @USER @USER How many verifiable lies has he to...     twitter_2
# 2     @USER @USER @USER Maybe Docs just a scrub of a...     twitter_3
# 3     @USER @USER is just a cover up for the real ha...     twitter_4
# 4     @USER @USER @USER The irony being that he even...     twitter_5
# ...                                                 ...           ...
# 1795  @USER @USER @USER is definitely the best out t...  twitter_1796
# 1796  @USER @USER Ye let her out run wild and infect...  twitter_1797
# 1797  @USER @USER @USER Thanks for that , I would ha...  twitter_1798
# 1798  @USER @USER @USER Yes also #found this on #new...  twitter_1799
# 1799  @USER @USER @USER you still need to send the l...  twitter_1800
#
#                                               context/4 context/5 context/6  \
# 0                                                   NaN       NaN       NaN
# 1                                                   NaN       NaN       NaN
# 2                                                   NaN       NaN       NaN
# 3                                                   NaN       NaN       NaN
# 4                                                   NaN       NaN       NaN
# ...                                                 ...       ...       ...
# 1795                                                NaN       NaN       NaN
# 1796                                                NaN       NaN       NaN
# 1797                                                NaN       NaN       NaN
# 1798  @USER @USER @USER I totally agree ! Music is s...       NaN       NaN
# 1799                                                NaN       NaN       NaN
#
#       ... context/9 context/10 context/11 context/12 context/13 context/14  \
# 0     ...       NaN        NaN        NaN        NaN        NaN        NaN
# 1     ...       NaN        NaN        NaN        NaN        NaN        NaN
# 2     ...       NaN        NaN        NaN        NaN        NaN        NaN
# 3     ...       NaN        NaN        NaN        NaN        NaN        NaN
# 4     ...       NaN        NaN        NaN        NaN        NaN        NaN
# ...   ...       ...        ...        ...        ...        ...        ...
# 1795  ...       NaN        NaN        NaN        NaN        NaN        NaN
# 1796  ...       NaN        NaN        NaN        NaN        NaN        NaN
# 1797  ...       NaN        NaN        NaN        NaN        NaN        NaN
# 1798  ...       NaN        NaN        NaN        NaN        NaN        NaN
# 1799  ...       NaN        NaN        NaN        NaN        NaN        NaN
#
#      context/15 context/16 context/17  \
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 1795        NaN        NaN        NaN
# 1796        NaN        NaN        NaN
# 1797        NaN        NaN        NaN
# 1798        NaN        NaN        NaN
# 1799        NaN        NaN        NaN
#
#                                            concat_tweet
# 0     @USER @USER @USER My 3 year old , that just fi...
# 1     @USER @USER How many verifiable lies has he to...
# 2     @USER @USER @USER Maybe Docs just a scrub of a...
# 3     @USER @USER is just a cover up for the real ha...
# 4     @USER @USER @USER The irony being that he even...
# ...                                                 ...
# 1795  @USER @USER @USER is definitely the best out t...
# 1796  @USER @USER Ye let her out run wild and infect...
# 1797  @USER @USER @USER Thanks for that , I would ha...
# 1798  @USER @USER @USER Yes also #found this on #new...
# 1799  @USER @USER @USER you still need to send the l...
#
# [1800 rows x 22 columns]

# %%
new_df = df.drop(['context/2','context/3','context/4','context/5','context/6','context/7','context/8','context/9','context/10','context/11','context/12','context/13','context/14','context/15','context/16','context/17','id'], axis=1)

# %%
new_df
# Out:
#             label                                          context/0  \
# 0     NOT_SARCASM             Well now that ’ s problematic AF <URL>
# 1         SARCASM  Last week the Fake News said that a section of...
# 2         SARCASM  @USER Let ’ s Aplaud Brett When he deserves it...
# 3     NOT_SARCASM  Women generally hate this president . What's u...
# 4     NOT_SARCASM  Dear media Remoaners , you excitedly sharing c...
# ...           ...                                                ...
# 1795  NOT_SARCASM  I have been a business customer of MWeb @USER ...
# 1796      SARCASM  A woman refuses to have her temperature taken ...
# 1797      SARCASM  The reason big government wants @USER out is b...
# 1798  NOT_SARCASM  Happy #musicmonday and #thanks for #all your 😎...
# 1799  NOT_SARCASM  Not long wrapped on the amazing #January22nd W...
#
#                                               context/1  \
# 0     @USER @USER My 5 year old ... asked me why the...
# 1     @USER The mainstream media doesn't report the ...
# 2     @USER @USER He did try keep korkmaz in in the ...
# 3     @USER I've hated him before he was placed in o...
# 4     @USER When Spiked claim that Brexiteers knew e...
# ...                                                 ...
# 1795  @USER @USER It ’ s time for @USER , 24/7 frien...
# 1796           @USER Disgusting i hope this world burns
# 1797  @USER @USER They ’ re already not allowed , it...
# 1798  @USER @USER @USER Happy #MusicMonday to you to...
# 1799  @USER @USER Two phenomenal women . Much love t...
#
#                                                response  \
# 0     @USER @USER @USER My 3 year old , that just fi...
# 1     @USER @USER How many verifiable lies has he to...
# 2     @USER @USER @USER Maybe Docs just a scrub of a...
# 3     @USER @USER is just a cover up for the real ha...
# 4     @USER @USER @USER The irony being that he even...
# ...                                                 ...
# 1795  @USER @USER @USER is definitely the best out t...
# 1796  @USER @USER Ye let her out run wild and infect...
# 1797  @USER @USER @USER Thanks for that , I would ha...
# 1798  @USER @USER @USER Yes also #found this on #new...
# 1799  @USER @USER @USER you still need to send the l...
#
#                                            concat_tweet
# 0     @USER @USER @USER My 3 year old , that just fi...
# 1     @USER @USER How many verifiable lies has he to...
# 2     @USER @USER @USER Maybe Docs just a scrub of a...
# 3     @USER @USER is just a cover up for the real ha...
# 4     @USER @USER @USER The irony being that he even...
# ...                                                 ...
# 1795  @USER @USER @USER is definitely the best out t...
# 1796  @USER @USER Ye let her out run wild and infect...
# 1797  @USER @USER @USER Thanks for that , I would ha...
# 1798  @USER @USER @USER Yes also #found this on #new...
# 1799  @USER @USER @USER you still need to send the l...
#
# [1800 rows x 5 columns]

# %% [markdown]
# # Preprocess

# %%
def process_file(text):
    #put text in all lower case letters 
    #all_text = text.lower()
    all_text = text

    #remove all non-alphanumeric chars
    #all_text = re.sub(r"[^a-zA-Z0-9]", " ", all_text)
    #remove newlines/tabs, etc. so it's easier to match phrases, later
    all_text = re.sub(r"\t", " ", all_text)
    all_text = re.sub(r"\n", " ", all_text)
    all_text = re.sub("  ", " ", all_text)
    all_text = re.sub("   ", " ", all_text)
    all_text = re.sub(r'(@USER)', ' ', all_text)
    return all_text

def create_text_column(df):
  #create copy to modify
  text_df = df.copy()
    
  #store processed text
  response = []
    
    
      # for each file (row) in the df, read in the file 
  for row_i in df.index:
      filename = df.iloc[row_i]['response']
      file_text = process_file(str(filename))
          #append processed text to list
      response.append(file_text)
    
    #add column to the copied dataframe
  text_df['response'] = response

  context_0 = []
  for row_i in df.index:
      filename = df.iloc[row_i]['context/0']
      file_text = process_file(str(filename))
          #append processed text to list
      context_0.append(file_text)
    
    #add column to the copied dataframe
  text_df['context/0']=context_0
  context_1= []
  for row_i in df.index:
      filename = df.iloc[row_i]['context/1']
      file_text = process_file(str(filename))
          #append processed text to list
      context_1.append(file_text)
    
    #add column to the copied dataframe
  text_df['context/1']= context_1
                                
  concat_tweet = []
  for row_i in df.index:
      filename = df.iloc[row_i]['concat_tweet']
      file_text = process_file(str(filename))
          #append processed text to list
      concat_tweet.append(file_text)
    
    #add column to the copied dataframe
  text_df['concat_tweet']= concat_tweet                           
                                
    
  return text_df

# %%
new_df = create_text_column(new_df)

# %%
new_df
# Out:
#             label                                          context/0  \
# 0     NOT_SARCASM             Well now that ’ s problematic AF <URL>
# 1         SARCASM  Last week the Fake News said that a section of...
# 2         SARCASM    Let ’ s Aplaud Brett When he deserves it he ...
# 3     NOT_SARCASM  Women generally hate this president . What's u...
# 4     NOT_SARCASM  Dear media Remoaners , you excitedly sharing c...
# ...           ...                                                ...
# 1795  NOT_SARCASM  I have been a business customer of MWeb   for ...
# 1796      SARCASM  A woman refuses to have her temperature taken ...
# 1797      SARCASM  The reason big government wants   out is becau...
# 1798  NOT_SARCASM  Happy #musicmonday and #thanks for #all your 😎...
# 1799  NOT_SARCASM  Not long wrapped on the amazing #January22nd W...
#
#                                               context/1  \
# 0         My 5 year old ... asked me why they are ma...
# 1       The mainstream media doesn't report the fact...
# 2         He did try keep korkmaz in in the 4th quar...
# 3       I've hated him before he was placed in offic...
# 4       When Spiked claim that Brexiteers knew exact...
# ...                                                 ...
# 1795      It ’ s time for   , 24/7 friendly customer...
# 1796                 Disgusting i hope this world burns
# 1797      They ’ re already not allowed , it ’ s cal...
# 1798        Happy #MusicMonday to you too ! What are...
# 1799      Two phenomenal women . Much love to you bo...
#
#                                                response  \
# 0           My 3 year old , that just finished readi...
# 1         How many verifiable lies has he told now ?...
# 2           Maybe Docs just a scrub of a coach ... I...
# 3         is just a cover up for the real hate insid...
# 4           The irony being that he even has to ask ...
# ...                                                 ...
# 1795        is definitely the best out there . No qu...
# 1796      Ye let her out run wild and infect 10000 m...
# 1797        Thanks for that , I would have never kno...
# 1798        Yes also #found this on #new with loads ...
# 1799        you still need to send the link to the f...
#
#                                            concat_tweet
# 0           My 3 year old , that just finished readi...
# 1         How many verifiable lies has he told now ?...
# 2           Maybe Docs just a scrub of a coach ... I...
# 3         is just a cover up for the real hate insid...
# 4           The irony being that he even has to ask ...
# ...                                                 ...
# 1795        is definitely the best out there . No qu...
# 1796      Ye let her out run wild and infect 10000 m...
# 1797        Thanks for that , I would have never kno...
# 1798        Yes also #found this on #new with loads ...
# 1799        you still need to send the link to the f...
#
# [1800 rows x 5 columns]

# %%
## Function to get Emotion Vectors
from transformers import AutoTokenizer, AutoModelWithLMHead

tokenizer = AutoTokenizer.from_pretrained("mrm8488/t5-base-finetuned-emotion")

model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-emotion")

def get_emotion(text):
  input_ids = tokenizer.encode(text + '</s>', return_tensors='pt')

  output = model.generate(input_ids=input_ids,
               max_length=2)

  dec = [tokenizer.decode(ids) for ids in output]
  label = dec[0]
  return input_ids

# %%
#Function to get Emotion labels

from transformers import AutoTokenizer, AutoModelWithLMHead

tokenizer = AutoTokenizer.from_pretrained("mrm8488/t5-base-finetuned-emotion")

model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-emotion")

def get_emotion_label(text):
  input_ids = tokenizer.encode(text + '</s>', return_tensors='pt')

  output = model.generate(input_ids=input_ids,
               max_length=2)

  dec = [tokenizer.decode(ids) for ids in output]
  label = dec[0]
  return label

# %%
# creating lists to keep pos, neu, neg, and compound scores --- later to be used to create a dataframe
response_sent = []



# extracting vader scores for each entry in the data
# (we're not using context yet.)
# note that the compound score is rescaled to the [0,1] range
# some classiifers don't take negative values (e.g., MultinomialNB)

for row in new_df["response"]:
    sentiment = get_emotion_label(row)
  
    response_sent.append(sentiment)


##Create feature vector 
new_df["Response_emotion"] = response_sent

# %%
# creating lists to keep pos, neu, neg, and compound scores --- later to be used to create a dataframe
context_sent = []



# extracting vader scores for each entry in the data
# (we're not using context yet.)
# note that the compound score is rescaled to the [0,1] range
# some classiifers don't take negative values (e.g., MultinomialNB)

for row in new_df["context/0"]:
    if row == 0:
        
        sentiment = 'NaN'
  
        context_sent.append(sentiment)
    else:
        
        sentiment = get_emotion_label(row)
        context_sent.append(sentiment)
        


##Create feature vector 
new_df["context0_sentiment"] = context_sent

# %%
# creating lists to keep pos, neu, neg, and compound scores --- later to be used to create a dataframe
concat_sent = []



# extracting vader scores for each entry in the data
# (we're not using context yet.)
# note that the compound score is rescaled to the [0,1] range
# some classiifers don't take negative values (e.g., MultinomialNB)

for row in new_df["concat_tweet"]:
    if row == 0:
        
        sentiment = 'NaN'
  
        context_sent.append(sentiment)
    else:
        
        sentiment = get_emotion_label(row)
        context_sent.append(sentiment)
        


##Create feature vector 
new_df["concat_emotion"] = concat_sent
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-601729dda96d> in <module>
#      23
#      24 ##Create feature vector
# ---> 25 new_df["concat_emotion"] = concat_sent
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
new_df
# Out:
#             label                                          context/0  \
# 0     NOT_SARCASM             Well now that ’ s problematic AF <URL>
# 1         SARCASM  Last week the Fake News said that a section of...
# 2         SARCASM    Let ’ s Aplaud Brett When he deserves it he ...
# 3     NOT_SARCASM  Women generally hate this president . What's u...
# 4     NOT_SARCASM  Dear media Remoaners , you excitedly sharing c...
# ...           ...                                                ...
# 1795  NOT_SARCASM  I have been a business customer of MWeb   for ...
# 1796      SARCASM  A woman refuses to have her temperature taken ...
# 1797      SARCASM  The reason big government wants   out is becau...
# 1798  NOT_SARCASM  Happy #musicmonday and #thanks for #all your 😎...
# 1799  NOT_SARCASM  Not long wrapped on the amazing #January22nd W...
#
#                                               context/1  \
# 0         My 5 year old ... asked me why they are ma...
# 1       The mainstream media doesn't report the fact...
# 2         He did try keep korkmaz in in the 4th quar...
# 3       I've hated him before he was placed in offic...
# 4       When Spiked claim that Brexiteers knew exact...
# ...                                                 ...
# 1795      It ’ s time for   , 24/7 friendly customer...
# 1796                 Disgusting i hope this world burns
# 1797      They ’ re already not allowed , it ’ s cal...
# 1798        Happy #MusicMonday to you too ! What are...
# 1799      Two phenomenal women . Much love to you bo...
#
#                                                response  \
# 0           My 3 year old , that just finished readi...
# 1         How many verifiable lies has he told now ?...
# 2           Maybe Docs just a scrub of a coach ... I...
# 3         is just a cover up for the real hate insid...
# 4           The irony being that he even has to ask ...
# ...                                                 ...
# 1795        is definitely the best out there . No qu...
# 1796      Ye let her out run wild and infect 10000 m...
# 1797        Thanks for that , I would have never kno...
# 1798        Yes also #found this on #new with loads ...
# 1799        you still need to send the link to the f...
#
#                                            concat_tweet Response_emotion  \
# 0           My 3 year old , that just finished readi...              joy
# 1         How many verifiable lies has he told now ?...              joy
# 2           Maybe Docs just a scrub of a coach ... I...            anger
# 3         is just a cover up for the real hate insid...            anger
# 4           The irony being that he even has to ask ...            anger
# ...                                                 ...              ...
# 1795        is definitely the best out there . No qu...              joy
# 1796      Ye let her out run wild and infect 10000 m...             fear
# 1797        Thanks for that , I would have never kno...              joy
# 1798        Yes also #found this on #new with loads ...              joy
# 1799        you still need to send the link to the f...              joy
#
#      context0_sentiment
# 0                 anger
# 1                  fear
# 2                   joy
# 3                 anger
# 4                 anger
# ...                 ...
# 1795              anger
# 1796              anger
# 1797              anger
# 1798                joy
# 1799                joy
#
# [1800 rows x 7 columns]

# %%
new_df.to_csv('final_test_emotions.csv')

# %% [markdown]
# # Import cosingn similarity for training data

# %%
##TODO

csv_file = '/Users/swcam/Documents/GitHub/Sarcasm/test data sarcasm cosine.csv'

cosign_df = pd.read_csv(csv_file)

# print out the first few rows of data info
cosign_df.head(2)
# Out:
#    Unnamed: 0                                          context/0  \
# 0           0             Well now that ’ s problematic AF <URL>
# 1           1  Last week the Fake News said that a section of...
#
#                                            context/1  \
# 0  @USER @USER My 5 year old ... asked me why the...
# 1  @USER The mainstream media doesn't report the ...
#
#                                            context/2  \
# 0  @USER @USER @USER I will take shit that didn't...
# 1                                                NaN
#
#                                            context/3  \
# 0  @USER @USER @USER No .. he actually in the gif...
# 1                                                NaN
#
#                                             response         id context/4  \
# 0  @USER @USER @USER My 3 year old , that just fi...  twitter_1       NaN
# 1  @USER @USER How many verifiable lies has he to...  twitter_2       NaN
#
#   context/5 context/6  ... context/10 context/11 context/12 context/13  \
# 0       NaN       NaN  ...        NaN        NaN        NaN        NaN
# 1       NaN       NaN  ...        NaN        NaN        NaN        NaN
#
#   context/14 context/15 context/16 context/17 cos_sim cos_sim1
# 0        NaN        NaN        NaN        NaN   0.817    0.828
# 1        NaN        NaN        NaN        NaN   0.859    0.849
#
# [2 rows x 23 columns]

# %%
new_cosign_df = cosign_df[['cos_sim','cos_sim1']].copy()

# %%
new_cosign_df
# Out:
#       cos_sim  cos_sim1
# 0       0.817     0.828
# 1       0.859     0.849
# 2       0.807     0.853
# 3       0.814     0.892
# 4       0.861     0.875
# ...       ...       ...
# 1795    0.873     0.910
# 1796    0.787     0.777
# 1797    0.815     0.796
# 1798    0.390     0.773
# 1799    0.824     0.843
#
# [1800 rows x 2 columns]

# %%
## Combine original emotion df with cosing similarity df

final_df = pd.concat([new_df, new_cosign_df], axis=1)

# %%
final_df
# Out:
#             label                                          context/0  \
# 0     NOT_SARCASM             Well now that ’ s problematic AF <URL>
# 1         SARCASM  Last week the Fake News said that a section of...
# 2         SARCASM    Let ’ s Aplaud Brett When he deserves it he ...
# 3     NOT_SARCASM  Women generally hate this president . What's u...
# 4     NOT_SARCASM  Dear media Remoaners , you excitedly sharing c...
# ...           ...                                                ...
# 1795  NOT_SARCASM  I have been a business customer of MWeb   for ...
# 1796      SARCASM  A woman refuses to have her temperature taken ...
# 1797      SARCASM  The reason big government wants   out is becau...
# 1798  NOT_SARCASM  Happy #musicmonday and #thanks for #all your 😎...
# 1799  NOT_SARCASM  Not long wrapped on the amazing #January22nd W...
#
#                                               context/1  \
# 0         My 5 year old ... asked me why they are ma...
# 1       The mainstream media doesn't report the fact...
# 2         He did try keep korkmaz in in the 4th quar...
# 3       I've hated him before he was placed in offic...
# 4       When Spiked claim that Brexiteers knew exact...
# ...                                                 ...
# 1795      It ’ s time for   , 24/7 friendly customer...
# 1796                 Disgusting i hope this world burns
# 1797      They ’ re already not allowed , it ’ s cal...
# 1798        Happy #MusicMonday to you too ! What are...
# 1799      Two phenomenal women . Much love to you bo...
#
#                                                response  \
# 0           My 3 year old , that just finished readi...
# 1         How many verifiable lies has he told now ?...
# 2           Maybe Docs just a scrub of a coach ... I...
# 3         is just a cover up for the real hate insid...
# 4           The irony being that he even has to ask ...
# ...                                                 ...
# 1795        is definitely the best out there . No qu...
# 1796      Ye let her out run wild and infect 10000 m...
# 1797        Thanks for that , I would have never kno...
# 1798        Yes also #found this on #new with loads ...
# 1799        you still need to send the link to the f...
#
#                                            concat_tweet Response_emotion  \
# 0           My 3 year old , that just finished readi...              joy
# 1         How many verifiable lies has he told now ?...              joy
# 2           Maybe Docs just a scrub of a coach ... I...            anger
# 3         is just a cover up for the real hate insid...            anger
# 4           The irony being that he even has to ask ...            anger
# ...                                                 ...              ...
# 1795        is definitely the best out there . No qu...              joy
# 1796      Ye let her out run wild and infect 10000 m...             fear
# 1797        Thanks for that , I would have never kno...              joy
# 1798        Yes also #found this on #new with loads ...              joy
# 1799        you still need to send the link to the f...              joy
#
#      context0_sentiment  cos_sim  cos_sim1
# 0                 anger    0.817     0.828
# 1                  fear    0.859     0.849
# 2                   joy    0.807     0.853
# 3                 anger    0.814     0.892
# 4                 anger    0.861     0.875
# ...                 ...      ...       ...
# 1795              anger    0.873     0.910
# 1796              anger    0.787     0.777
# 1797              anger    0.815     0.796
# 1798                joy    0.390     0.773
# 1799                joy    0.824     0.843
#
# [1800 rows x 9 columns]

# %%
final_df.to_csv('final_test_emotions_cosign')
